# %%
#Read the three files into python as dataframes
import pandas as pd  # keywords are highlighted in green, other strings in red, etc.
import numpy as np
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
file3['Customer Lifetime Value'].dtypes #file type
# Out:
# dtype('float64')

# %%
file1['Customer Lifetime Value'][4003] #value at 4003 row
# Out:
# nan

# %%
#Heading of coloum
column_names = file1.columns
column_names
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
#Repalcing % value
file1['Customer Lifetime Value'] = file1['Customer Lifetime Value'].str.replace('%','')

# %%
#Repalcing % value and converting to float
file1['Customer Lifetime Value'].astype(float)
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 4003           NaN
# 4004           NaN
# 4005           NaN
# 4006           NaN
# 4007           NaN
# Name: Customer Lifetime Value, Length: 4008, dtype: float64

# %%
column_names = file2.columns
column_names
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Total Claim Amount', 'Policy Type', 'Vehicle Class'],
#       dtype='object')

# %%
#Show the DataFrame's shape.
column_names = file3.columns
column_names
data.shape
# Out:
# (12074, 13)

# %%
#Concatenate the three dataframes
data = pd.concat([file1, file2, file3], axis=0) #discuss axis here
data.shape
# Out:
# (12074, 13)

# %%
#Standardize header names
data = data.rename(columns={'Customer':'Customer_id',
                            'ST':'US_State', 
                            'GENDER':'Gender_f_m'})
data.head()
#data.shape
# Out:
#   Customer_id    US_State Gender_f_m             Education  \
# 0     RB50392  Washington        NaN                Master
# 1     QZ44356     Arizona          F              Bachelor
# 2     AI49188      Nevada          F              Bachelor
# 3     WW63253  California          M              Bachelor
# 4     GA49547  Washington          M  High School or Below
#
#   Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                     NaN      0.0                1000.0
# 1               697953.59      0.0                  94.0
# 2              1288743.17  48767.0                 108.0
# 3               764586.18      0.0                 106.0
# 4               536307.65  36357.0                  68.0
#
#   Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                    1/0/00   Personal Auto  Four-Door Car
# 1                    1/0/00   Personal Auto  Four-Door Car
# 2                    1/0/00   Personal Auto   Two-Door Car
# ...

# %%
#checking Which columns are numerical?
#checking Which columns are categorical?
data.dtypes
# Out:
# Customer_id                   object
# US_State                      object
# Gender_f_m                    object
# Education                     object
# Customer Lifetime Value       object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints     object
# Policy Type                   object
# Vehicle Class                 object
# Total Claim Amount           float64
# State                         object
# Gender                        object
# dtype: object

# %%
data.shape  #DataFrame's shape
# Out:
# (12074, 13)

# %%
#Delete the column education and the number of open complaints from the dataframe.
data2 = data.copy()
data2 = data2.drop(['Education','Number of Open Complaints'],axis=1)
print(data2.shape)
data2.head()
# Out:
# (12074, 11)
#   Customer_id    US_State Gender_f_m Customer Lifetime Value   Income  \
# 0     RB50392  Washington        NaN                     NaN      0.0
# 1     QZ44356     Arizona          F               697953.59      0.0
# 2     AI49188      Nevada          F              1288743.17  48767.0
# 3     WW63253  California          M               764586.18      0.0
# 4     GA49547  Washington          M               536307.65  36357.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
#
#   State Gender
# 0   NaN    NaN
# 1   NaN    NaN
# 2   NaN    NaN
# ...

# %%
#Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type
data2['Customer Lifetime Value'].astype(str)
data2['Customer Lifetime Value'] = data2['Customer Lifetime Value'].str.replace('%','')
data2['Customer Lifetime Value'].astype(float)
data2.shape
data2.head()
# Out:
#   Customer_id    US_State Gender_f_m Customer Lifetime Value   Income  \
# 0     RB50392  Washington        NaN                     NaN      0.0
# 1     QZ44356     Arizona          F               697953.59      0.0
# 2     AI49188      Nevada          F              1288743.17  48767.0
# 3     WW63253  California          M               764586.18      0.0
# 4     GA49547  Washington          M               536307.65  36357.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
#
#   State Gender
# 0   NaN    NaN
# 1   NaN    NaN
# 2   NaN    NaN
# 3   NaN    NaN
# ...

# %%
#Filter out the data for customers who have an income of 0 or less
data3 = data2[data2['Income']>0]
data3.head()
# Out:
#   Customer_id    US_State Gender_f_m Customer Lifetime Value   Income  \
# 2     AI49188      Nevada          F              1288743.17  48767.0
# 4     GA49547  Washington          M               536307.65  36357.0
# 5     OC83172      Oregon          F               825629.78  62902.0
# 6     XZ87318      Oregon          F               538089.86  55350.0
# 8     DY87989      Oregon          M              2412750.40  14072.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount  \
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
# 5                  69.0   Personal Auto   Two-Door Car          159.383042
# 6                  67.0  Corporate Auto  Four-Door Car          321.600000
# 8                  71.0  Corporate Auto  Four-Door Car          511.200000
#
#   State Gender
# 2   NaN    NaN
# 4   NaN    NaN
# 5   NaN    NaN
# 6   NaN    NaN
# ...

# %%
#Check for duplicate rows in the data and remove if any.
data5 = data2.drop(['State','Gender'],axis =1)
data5.head()
# Out:
#   Customer_id    US_State Gender_f_m Customer Lifetime Value   Income  \
# 0     RB50392  Washington        NaN                     NaN      0.0
# 1     QZ44356     Arizona          F               697953.59      0.0
# 2     AI49188      Nevada          F              1288743.17  48767.0
# 3     WW63253  California          M               764586.18      0.0
# 4     GA49547  Washington          M               536307.65  36357.0
#
#    Monthly Premium Auto     Policy Type  Vehicle Class  Total Claim Amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
